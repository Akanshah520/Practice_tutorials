# %% [markdown]
# # Aggregrating Data

# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %%
titanic = pd.read_csv("/content/titanic_kaggle.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
titanic['Name'].value_counts()
# Out:
# Name
# Peter, Master. Michael J                        1
# Kelly, Mr. James                                1
# Gale, Mr. Harry                                 1
# Bonnell, Miss. Caroline                         1
# Conlon, Mr. Thomas Henry                        1
#                                                ..
# Connolly, Miss. Kate                            1
# Svensson, Mr. Johan Cervin                      1
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# Wirz, Mr. Albert                                1
# Myles, Mr. Thomas Francis                       1
# Name: count, Length: 418, dtype: int64

# %%
titanic['Sex'].value_counts() #fairly distorted.
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
titanic[titanic['Sex']=='male']['Pclass'].value_counts()
# Out:
# Pclass
# 3    146
# 2     63
# 1     57
# Name: count, dtype: int64

# %%
titanic['Pclass'][titanic['Sex']== 'male'].value_counts()
# Out:
# Pclass
# 3    146
# 2     63
# 1     57
# Name: count, dtype: int64

# %%
titanic.groupby(['Sex'])['Survived'].sum()
# Out:
# Sex
# female    152
# male        0
# Name: Survived, dtype: int64

# %%
titanic[titanic['Sex']=='male']['Survived'].value_counts()
# Out:
# Survived
# 0    266
# Name: count, dtype: int64

# %%
titanic['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
print(titanic.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.groupby(['Survived','Pclass']).agg({'Fare':'mean','Ticket':'sum'})
# Out:
#                        Fare                                             Ticket
# Survived Pclass
# 0        1        75.586551  694PC 17603PC 1759711305413236113778PC 1759413...
#          2        20.184654  24027624873824065233734SC/AH 3085C.A. 31029SC/...
#          3        11.826350  3309113151547538A/4 488713492202692C 17368A/5....
# 1        1       115.591168  21228W.E.P. 5734PC 17598PC 1760811350911753118...
#          2        26.438750  SC/PARIS 216723724929105F.C.C. 13534SC/AH 2903...
#          3        13.735129  36327231012983309722657STON/O2. 31012702696C.A...

# %% [markdown]
# ## Pivot tables

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pivot = titanic.pivot(columns = 'PassengerId', index = 'Survived', values = 'Sex')

# %%
pivot
# Out:
# PassengerId  892     893   894   895     896   897     898   899     900   \
# Survived
# 0            male     NaN  male  male     NaN  male     NaN  male     NaN
# 1             NaN  female   NaN   NaN  female   NaN  female   NaN  female
#
# PassengerId  901   ...    1300    1301    1302    1303    1304  1305    1306  \
# Survived           ...
# 0            male  ...     NaN     NaN     NaN     NaN     NaN  male     NaN
# 1             NaN  ...  female  female  female  female  female   NaN  female
#
# PassengerId  1307  1308  1309
# Survived
# 0            male  male  male
# 1             NaN   NaN   NaN
#
# [2 rows x 418 columns]

# %%
titanic.shape
# Out:
# (418, 12)
